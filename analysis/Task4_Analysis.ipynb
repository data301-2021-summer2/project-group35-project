# %% [markdown]
# # Task 4. Conduct your analysis to help answer your research question(s)

# %% [markdown]
# Have you ever found yourself needing a car, but not knowing which manufacturer produces the best product? Walking into dealership after dealership only to have car salesmen trying to upsell and create a false brand identity of the quality of their vehicles. Well today I hope to educate you on which companies produce the best quality of car based upon the average mileage and build year (years since the model year) so you can make informed decisions and exclude the biases of pressureing dealerships. I would like to introduce you to my data analysis project, here we will be discussion and American used vehicles. To do this we will import a public dataset from Kaggle to conduct our research and ultimatly come to a conlusion.
#
# Below is an attached link to the exact data I used to come to my findings:
# https://www.kaggle.com/doaaalsenani/usa-cers-dataset
#
# ### Research Question:
#
# ##### What car manufacturer produces the longest lasting and best quality of cars based on model year and mileage?

# %% [markdown]
# ### Data
# To re-iterate, the data I have used is from a public data sharing website called Kaggle. This data has been recently updated. It has been scrapped from AUCTIONEXPORT.com, it includes information for 20 brands of used vehicles for sale in various states in the United States.
# Although there are various columns and data points, the main data that we are focusing on is:
#
# Brand/Manufacturer -> the brand of car
#
# Year/Model Year -> the vehicle regitration year
#
# Mileage -> distance travelled in the vehicle (in miles)
#
# These data point will guide us to our conclusion of what car is the best quality based on mileage and model year!

# %% [markdown]
# ### Methods
#
# To achieve my goal of understanding, I first imported the data frame, striped away all of the unnecessary data points and NaN values, plotted the values, and interpreted the graph. For a more in-depth view and reasoning behind my conclusions please visit "Milestone2.ipynb" and "ExploratoryDataAnalysis(EDA)onmyDataset.ipynb" files.

# %% [markdown]
# ### Analysis
# #### By Mileage

# %% [markdown]
# ![image.png](attachment:ce40972b-ac4a-4bbc-9111-f59003ff7864.png)

# %% [markdown]
# The by mileage analysis reveals that the longest lasting and this best quality cars come from the manufacturering companies Acura, Audi, Honda, Mazda, and Toyota. This statistic coorelates to the by year analysis because much of the same brands are leaders in the same catagory. To make this inference I looked at the companies with the highest mileage as well as the disrobution of those vehicles with the highest mileage. These companies are all leaders in this market segment and all by quite some margin!

# %% [markdown]
# #### By Year
# ![image.png](attachment:9c3f2abd-9fe3-44a4-8e8b-19f872b8fbb0.png)

# %% [markdown]
# When looking at the longest lasting cars by manufacturer, it is easy to see that the best quality of cars are Acura, Audi, Lincoln, Heartland, Toyota, and Mazda. To make this decision I looked at the median and location of the whiskers of each boxplot to make this inference.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# So, what car manufacturer produces the longest lasting and best quality of cars based on model year and mileage?

# %% [markdown]
# Well after I have conducted my study and analyzed the outcomes, I can confidently say that the manufacturers that produce the best quality cars for American use is Acura, Audi, Mazda, and Toyota. This is because these car manufacturers were front runners in both the by year and by mileage catagory. So my report is that the manufacturers of Acura, Audi, Mazda, and Toyota produce vehicles of quality, based on the years since their registration date, and the distance travelled within the vehicle (measured in miles).

# %% [markdown]
# ## Appendix/Sources

# %% [markdown]
# #### DataFrame used
# https://www.kaggle.com/doaaalsenani/usa-cers-dataset
